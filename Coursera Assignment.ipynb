# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Created By: Sherif Abbas                                         Title: A future Data Analyst and Strategic Planner

# %% [markdown]
# *I am interested in data science because I am really into analyzing data to get insights. Moreover, it is the future science.*

# %% [markdown]
# ### This code is created to implement a very simple calculation.

# %%
1+1
# Out:
# 2

# %%
print (" Congrats! the output is 2 ")
# Out:
#  *Congrats! the output is 2*

# %% [markdown]
# * In this note book we explained the following:
# ***
# 1. Marking down cell
# 2. foramting cells<br> Done
#
# ![Sherif.JPG](attachment:Sherif.JPG)
# https://www.youtube.com/
